# %% [markdown]
# # 04 Filling NA Values

# %%
import pandas as pd

# %%
ufo = pd.read_csv('https://bit.ly/uforeports')
# ufo.to_csv('../data/uforeports.csv')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_new = ufo.fillna('blank')

# %%
ufo_new.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca           blank       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro           blank          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           blank           OVAL    CO  2/15/1931 14:00
# 3               Abilene           blank           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair           blank          LIGHT    NY  4/18/1933 19:00

# %%
ufo_new = ufo.fillna({'Colors Reported': 'No Color', 'Shape Reported': 'No Shape'})

# %%
ufo_new
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca        No Color       TRIANGLE    NY
# 1               Willingboro        No Color          OTHER    NJ
# 2                   Holyoke        No Color           OVAL    CO
# 3                   Abilene        No Color           DISK    KS
# 4      New York Worlds Fair        No Color          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park        No Color       TRIANGLE    IL
# 18237           Spirit Lake        No Color           DISK    IA
# 18238           Eagle River        No Color       No Shape    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor        No Color           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...
