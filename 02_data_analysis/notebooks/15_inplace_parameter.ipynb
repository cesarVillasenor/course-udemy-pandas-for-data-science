# %% [markdown]
# # 15 Inplace Parameter

# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col='country')
# drinks.to_csv('../data/drinksbycountry.csv')
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.drop('total_litres_of_pure_alcohol', axis=1, inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings continent
# country
# Afghanistan              0                0              0      Asia
# Albania                 89              132             54    Europe
# Algeria                 25                0             14    Africa
# Andorra                245              138            312    Europe
# Angola                 217               57             45    Africa

# %%
drinks.drop('wine_servings', axis=1,)
# Out:
#              beer_servings  spirit_servings      continent
# country
# Afghanistan              0                0           Asia
# Albania                 89              132         Europe
# Algeria                 25                0         Africa
# Andorra                245              138         Europe
# Angola                 217               57         Africa
# ...                    ...              ...            ...
# Venezuela              333              100  South America
# Vietnam                111                2           Asia
# Yemen                    6                0           Asia
# Zambia                  32               19         Africa
# Zimbabwe                64               18         Africa
#
# [193 rows x 3 columns]

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings continent
# country
# Afghanistan              0                0              0      Asia
# Albania                 89              132             54    Europe
# Algeria                 25                0             14    Africa
# Andorra                245              138            312    Europe
# Angola                 217               57             45    Africa
